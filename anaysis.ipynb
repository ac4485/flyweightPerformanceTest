# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df_flyweight = pd.read_csv('./flyweight.csv',header=None)
df_nonflyweight = pd.read_csv('./nonflyweight.csv',header=None)
df_flyweight_d = pd.read_csv('./flyweight_d.csv',header=None)

df_flyweight_gar = pd.read_csv('./flyweight_garbage.csv',header=None)
df_nonflyweight_gar = pd.read_csv('./nonflyweight_garbage.csv',header=None)

# %%
sn.scatterplot(x=range(10001),y=df_flyweight.iloc[0,:])
# Out:
# <Axes: ylabel='0'>

# %%
sn.scatterplot(x=range(10001),y=df_nonflyweight.iloc[0,:])
# Out:
# <Axes: ylabel='0'>

# %%
sn.scatterplot(x=range(10001),y=df_flyweight_d.iloc[0,:])
# Out:
# <Axes: ylabel='0'>

# %%
sn.scatterplot(x=range(1001),y=df_flyweight_gar.iloc[0,:])
# Out:
# <Axes: ylabel='0'>

# %% [markdown]
# *_garbage.csv: Reason: garbage collected.

# %%
sn.scatterplot(x=range(1001),y=df_nonflyweight_gar.iloc[0,:])
# Out:
# <Axes: ylabel='0'>
